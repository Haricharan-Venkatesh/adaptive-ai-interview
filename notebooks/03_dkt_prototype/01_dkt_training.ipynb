# %% [markdown]
# # Deep Knowledge Tracing Prototype
#
# This notebook demonstrates how to train the PyTorch LSTM-based DKT model on synthetic data.

# %%
import sys
import os
sys.path.append(os.path.abspath('../../backend'))

from ai_models.knowledge_tracing.train_dkt import train_model

# %%
# Train a small model on synthetic data
train_model(epochs=3, batch_size=16, num_skills=20, lr=0.01, save_path='../../backend/checkpoints/test_dkt.pt')
